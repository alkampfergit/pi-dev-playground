// %% [markdown]
// # 00 — Hello TypeScript
//
// The simplest possible check: can we run **TypeScript** code in a Jupyter notebook via the **tslab** kernel? No dependencies, just `console.log`.
//
// Kernel must be **TypeScript** (top-right). If you see output below the cell, the toolchain works.

// %%
console.log("Hello from TypeScript in a notebook! 🎉");

// %%
// A tiny bit of real TypeScript: a typed function.
const greet = (name: string): string => `Hello, ${name}!`;
console.log(greet("pi.dev"));
